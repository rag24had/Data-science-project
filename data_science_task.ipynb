# %% [markdown]
# <a href="https://colab.research.google.com/github/rag24had/Data-science-project/blob/main/data_science_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("My first data science project")
# Out:
# My first data science project

# %%
print("Adding new changes")
# Out:
# Adding new changes
